# %%
from typing import Any
import json

# %%
obj : Any
with open("../data/raw/scrapped_data/celery_scrapped_data/scrapped_json.json", "rb") as o:
    obj = json.load(o)

# %%
unique = { each['title'] : each for each in obj }.values()

# %%
len(obj)
# Out:
# 39224

# %%
len(unique)
# Out:
# 20435

# %%
list(unique)
# Out:
# [{'_id': {'$oid': '621a40b7e811eb1197fac80f'},
#   'site': 'https://www.timesnewroman.ro/',
#   'domain': 'monden/',
#   'title': 'Licitaţia de la Nurnberg',
#   'content': 'Trei picturi semnate de Adolf Hitler au fost vândute cu 42.000 de euro, în cadrul unei licitaţii care a avut loc – unde altundeva? – la Nurnberg.Gurile rele spun însă că suma respectivă n-ar fi putut fi obţinută dacă Hitler nu ar fi pornit al doilea război mondial, un artificiu de PR jalnic prin care pictorul a reuşit să ajungă în atenţia presei.',
#   'date': {'$date': '2009-09-11T00:00:00Z'}},
#  {'_id': {'$oid': '621a40b7e811eb1197fac810'},
#   'site': 'https://www.timesnewroman.ro/',
#   'domain': 'monden/',
#   'title': 'Femei amuzate sexual',
# ...

# %%
with open("../data/raw/scrapped_data/celery_scrapped_data/scrapped_json_unique.json", "w", encoding ='utf8') as o:
    json.dump(list(unique), o, indent = 6, ensure_ascii=False)
